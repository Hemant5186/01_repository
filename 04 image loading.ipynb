# %%
pip install openvc-python pillow scikit-image -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement openvc-python (from versions: none)
# ERROR: No matching distribution found for openvc-python

# %%
pip install opencv-python pillow scikit-image -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (10.2.0)
# Collecting pillow
#   Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\lib\site-packages (0.22.0)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in c:\programdata\anaconda3\lib\site-packages (from scikit-image) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in c:\programdata\anaconda3\lib\site-packages (from scikit-image) (3.1)
# Requirement already satisfied: imageio>=2.33 in c:\programdata\anaconda3\lib\site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\anaconda3\lib\site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\programdata\anaconda3\lib\site-packages (from scikit-image) (23.1)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 1.9 MB/s eta 0:00:21
#    ---------------------------------------- 0.2/38.8 MB 3.4 MB/s eta 0:00:12
#     --------------------------------------- 0.5/38.8 MB 4.9 MB/s eta 0:00:08
#     --------------------------------------- 0.9/38.8 MB 5.8 MB/s eta 0:00:07
#    - -------------------------------------- 1.5/38.8 MB 7.7 MB/s eta 0:00:05
#    -- ------------------------------------- 2.8/38.8 MB 12.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.6/38.8 MB 15.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.5/38.8 MB 16.0 MB/s eta 0:00:03
#    ------ --------------------------------- 6.3/38.8 MB 16.2 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.8 MB 16.7 MB/s eta 0:00:02
#    -------- ------------------------------- 8.2/38.8 MB 17.0 MB/s eta 0:00:02
#    --------- ------------------------------ 9.2/38.8 MB 17.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.2/38.8 MB 17.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.8/38.8 MB 21.1 MB/s eta 0:00:02
#    ------------ --------------------------- 11.8/38.8 MB 22.6 MB/s eta 0:00:02
#    ------------ --------------------------- 12.5/38.8 MB 21.1 MB/s eta 0:00:02
#    ------------- -------------------------- 13.1/38.8 MB 20.5 MB/s eta 0:00:02
#    -------------- ------------------------- 13.9/38.8 MB 18.7 MB/s eta 0:00:02
#    -------------- ------------------------- 14.5/38.8 MB 18.2 MB/s eta 0:00:02
#    --------------- ------------------------ 15.2/38.8 MB 17.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.9/38.8 MB 17.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.6/38.8 MB 16.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.3/38.8 MB 16.4 MB/s eta 0:00:02
#    ------------------ --------------------- 18.0/38.8 MB 16.4 MB/s eta 0:00:02
#    ------------------- -------------------- 18.7/38.8 MB 16.0 MB/s eta 0:00:02
#    -------------------- ------------------- 19.4/38.8 MB 15.6 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/38.8 MB 15.2 MB/s eta 0:00:02
#    --------------------- ------------------ 20.9/38.8 MB 15.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.6/38.8 MB 15.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/38.8 MB 14.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.0/38.8 MB 14.9 MB/s eta 0:00:02
#    ------------------------ --------------- 23.8/38.8 MB 15.2 MB/s eta 0:00:01
#    ------------------------- -------------- 24.5/38.8 MB 15.2 MB/s eta 0:00:01
#    -------------------------- ------------- 25.3/38.8 MB 15.2 MB/s eta 0:00:01
#    -------------------------- ------------- 26.0/38.8 MB 15.2 MB/s eta 0:00:01
#    --------------------------- ------------ 26.8/38.8 MB 15.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.5/38.8 MB 15.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.2/38.8 MB 15.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.0/38.8 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 29.7/38.8 MB 15.6 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.8 MB 15.6 MB/s eta 0:00:01
#    ------------------------------- -------- 31.0/38.8 MB 15.6 MB/s eta 0:00:01
#    -------------------------------- ------- 31.8/38.8 MB 15.2 MB/s eta 0:00:01
#    --------------------------------- ------ 32.3/38.8 MB 15.6 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/38.8 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.4/38.8 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.9/38.8 MB 14.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.4/38.8 MB 14.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.0/38.8 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.8 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.1/38.8 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 36.6/38.8 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.8 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.8/38.8 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  38.4/38.8 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 11.3 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------- ----------------------------- 0.7/2.6 MB 21.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.6 MB 15.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 14.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 12.5 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp311-cp311-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.7/12.8 MB 15.0 MB/s eta 0:00:01
#    --- ------------------------------------ 1.2/12.8 MB 15.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.9/12.8 MB 14.7 MB/s eta 0:00:01
#    ------- -------------------------------- 2.4/12.8 MB 13.8 MB/s eta 0:00:01
#    --------- ------------------------------ 3.0/12.8 MB 13.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.6/12.8 MB 13.6 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.8 MB 13.4 MB/s eta 0:00:01
#    -------------- ------------------------- 4.8/12.8 MB 13.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.4/12.8 MB 13.3 MB/s eta 0:00:01
#    ------------------ --------------------- 6.0/12.8 MB 13.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.2/12.8 MB 13.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.8/12.8 MB 13.1 MB/s eta 0:00:01
#    -------------------------- ------------- 8.5/12.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.1/12.8 MB 13.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.8 MB 13.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.3/12.8 MB 13.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.9/12.8 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.8 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.8 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.8 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 12.6 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Installing collected packages: pillow, opencv-python, lazy-loader, scikit-image
# Successfully installed lazy-loader-0.4 opencv-python-4.10.0.84 pillow-10.4.0 scikit-image-0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
# https://mitu.co.in/dataset
# Download all the files from /images folder and store in your
# curren working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %% [markdown]
# ##### using opencv

# %%
img1 = cv2.imread('images/caves.jpg')

# %%
cv2.imshow('First Image', img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Using Matplotlib

# %%
import matplotlib.pyplot as pltdata:image/png;base64,...

# %%
img_plt = plt.imread('images/caves.jpg')

# %%
plt.imshow(img_plt)

# %% [markdown]
# ##### Using scikit-image

# %%
from skimage import io

# %%
img_ski = io.imread('images/lenna.png')

# %%
plt.imshow(img_ski)

# %% [markdown]
# ##### Using Pillow

# %%
from PIL import Image

# %%
img_pil =Image.open('images/cat_damaged.png')

# %%
img_pil.show()

# %% [markdown]
# ##### Using tesorflow method

# %%
import tensorflow as tf
img_tf = tf.io.read_file('images/lenna.png')
img_tf = tf.image.decode_image(img_tf, channels=3)

# %%
plt.imshow(img_tf)

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
img1
# Out:
# array([[[117, 118, 122],
#         [ 62,  63,  67],
#         [ 39,  38,  40],
#         ...,
#         [ 15,  14,  18],
#         [ 15,  14,  16],
#         [ 15,  14,  16]],
#
#        [[ 91,  92,  96],
#         [ 52,  53,  57],
#         [ 39,  38,  40],
#         ...,
#         [ 16,  15,  19],
#         [ 17,  16,  18],
#         [ 14,  13,  15]],
#
#        [[ 77,  76,  78],
#         [ 45,  44,  46],
#         [ 33,  30,  32],
#         ...,
#         [ 17,  16,  20],
#         [ 16,  15,  19],
#         [ 15,  14,  18]],
#
#        ...,
#
#        [[169, 178, 181],
#         [169, 178, 181],
#         [158, 170, 172],
#         ...,
#         [152, 157, 158],
#         [163, 167, 168],
#         [166, 170, 171]],
#
#        [[166, 174, 174],
#         [158, 168, 168],
#         [147, 159, 159],
#         ...,
#         [163, 169, 168],
#         [165, 170, 169],
#         [168, 173, 172]],
#
#        [[155, 163, 163],
#         [144, 154, 154],
#         [140, 152, 152],
#         ...,
#         [188, 194, 193],
#         [178, 183, 182],
#         [173, 178, 177]]], dtype=uint8)

# %%
img1.shape
# Out:
# (534, 400, 3)

# %%
img_plt.shape
# Out:
# (400, 534, 3)

# %%
img_ski.shape
# Out:
# (512, 512, 3)

# %%
img_tf.shape
# Out:
# TensorShape([512, 512, 3])

# %%
img_pil.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 img_pil.shape
#
# AttributeError: 'PngImageFile' object has no attribute 'shape'

# %%
type(img1),type(img_plt)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
img1.dtype, img_plt.dtype
# Out:
# (dtype('uint8'), dtype('uint8'))

# %%
img1
# Out:
# array([[[117, 118, 122],
#         [ 62,  63,  67],
#         [ 39,  38,  40],
#         ...,
#         [ 15,  14,  18],
#         [ 15,  14,  16],
#         [ 15,  14,  16]],
#
#        [[ 91,  92,  96],
#         [ 52,  53,  57],
#         [ 39,  38,  40],
#         ...,
#         [ 16,  15,  19],
#         [ 17,  16,  18],
#         [ 14,  13,  15]],
#
#        [[ 77,  76,  78],
#         [ 45,  44,  46],
#         [ 33,  30,  32],
#         ...,
#         [ 17,  16,  20],
#         [ 16,  15,  19],
#         [ 15,  14,  18]],
#
#        ...,
#
#        [[169, 178, 181],
#         [169, 178, 181],
#         [158, 170, 172],
#         ...,
#         [152, 157, 158],
#         [163, 167, 168],
#         [166, 170, 171]],
#
#        [[166, 174, 174],
#         [158, 168, 168],
#         [147, 159, 159],
#         ...,
#         [163, 169, 168],
#         [165, 170, 169],
#         [168, 173, 172]],
#
#        [[155, 163, 163],
#         [144, 154, 154],
#         [140, 152, 152],
#         ...,
#         [188, 194, 193],
#         [178, 183, 182],
#         [173, 178, 177]]], dtype=uint8)

# %%
img_plt
# Out:
# array([[[ 16,  14,  15],
#         [ 15,  13,  14],
#         [ 18,  14,  15],
#         ...,
#         [171, 170, 166],
#         [172, 173, 168],
#         [177, 178, 173]],
#
#        [[ 16,  14,  15],
#         [ 18,  16,  17],
#         [ 19,  15,  16],
#         ...,
#         [168, 167, 163],
#         [169, 170, 165],
#         [182, 183, 178]],
#
#        [[ 18,  14,  15],
#         [ 19,  15,  16],
#         [ 20,  16,  17],
#         ...,
#         [158, 157, 152],
#         [168, 169, 163],
#         [193, 194, 188]],
#
#        ...,
#
#        [[ 40,  38,  39],
#         [ 40,  38,  39],
#         [ 32,  30,  33],
#         ...,
#         [172, 170, 158],
#         [159, 159, 147],
#         [152, 152, 140]],
#
#        [[ 67,  63,  62],
#         [ 57,  53,  52],
#         [ 46,  44,  45],
#         ...,
#         [181, 178, 169],
#         [168, 168, 158],
#         [154, 154, 144]],
#
#        [[122, 118, 117],
#         [ 96,  92,  91],
#         [ 78,  76,  77],
#         ...,
#         [181, 178, 169],
#         [174, 174, 166],
#         [163, 163, 155]]], dtype=uint8)

# %%
import numpy as np

# %%
img_new = np.zeros([100,100])

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_new[34,57] = 0.5

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_new[34] = 1

# %%
plt.imshow(img_new, cmap='gray')

# %%
np.random.randint(12, 78)
# Out:
# 54

# %%
img_new = np.zeros([100,100], dtype=np.uint8)

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j] = np.random.randint(0,255)

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_gray = cv2.imread('images/lena.png', 0)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
img_plt.shape
# Out:
# (400, 534, 3)

# %%
r = img_plt[:,:,0]
g = img_plt[:,:,1]
b = img_plt[:,:,2]

# %%
r.shape, g.shape, b.shape
# Out:
# ((400, 534), (400, 534), (400, 534))

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='gray')
plt.subplot(1,3,2)
plt.imshow(g, cmap='gray')
plt.subplot(1,3,3)
plt.imshow(b, cmap='gray')

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g, cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b, cmap='Blues')

# %%
new_img = (r+g+b) / 3

# %%
plt.imshow(new_img, cmap='gray')

# %%
plt.subplot(1,2,1)
plt.title('Image Read using cv2')
plt.imshow(img1)
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
img2 = cv2.cvtColor(img_plt, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.title('Image Read using cv2')
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
import sys

# %%
sys.getsizeof(img1)
# Out:
# 640944

# %%
sys.getsizeof(img_ski)
# Out:
# 786576
