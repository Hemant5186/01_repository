# %% [markdown]
# ### HEMANT KUMAR
# ##### https://mitu.co.in/submit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1
df = pd.read_csv('datasets/grapes_new.csv')

# %%
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
# ...

# %% [markdown]
# ##### Separate the input and output variables

# %%
# 2
x = df.drop('CLASS', axis = 1)
y = df['CLASS']

# %%
# 3
df.isnull().sum()
#df.fillna(df.mean(), inplace=True)
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
# 4
sns.countplot(x = 'CLASS', data=df)
plt.title('Count of Each Class')
plt.show()

# %%
df['CLASS'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of class')
plt.ylabel('')
plt.show()

# %%
# 5
sns.countplot(x='SHAPE', data=df)
plt.title('Count of each shape')
plt.show()

# %%
df['SHAPE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of class')
plt.ylabel('')
plt.show()

# %%
# count plot for soil_type
sns.countplot(x ='SOIL_TYPE', data=df)
plt.title('count of each soil type')
plt.show()

# %%
df['SOIL_TYPE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Soil Type')
plt.ylabel('')
plt.show()

# %%
# 6
features = ['ALCOHOL_PER','TEMPERATURE','AVG_HUMIDITY','FERT_NITRO_PER','WATER_PH']
for feature in features:
    sns.kdeplot(df[features], shade=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.show()
# Out:
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_15740\3560126204.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[features], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_15740\3560126204.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[features], shade=True)
# ...

# %%
#7 
from sklearn.preprocessing import LabelEncoder
categorial_columns = ['SHAPE', 'SOIL_TYPE']
label_encoders = {}
for column in categorial_columns:
    le = LabelEncoder()
    data[df] = le.fit_transform(data[column])
    label_encoders[column] =le
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 7
#       5 for column in categorial_columns:
#       6     le = LabelEncoder()
# ----> 7     data[df] = le.fit_transform(data[column])
#       8     label_encoders[column] =le
#
# NameError: name 'data' is not defined

# %%
#8 
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder

ctg_col = df.select_dtypes(include = ['object']).columns
label_encoders={}

for col in categorial_columns:
    le = LebelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] =le

selector = SelectKBest(chi2, k=5)
selector.fit(x,y)
x_selected = selector.transform(x)

selected_features = x.columns[selector.get_support()]
print(f"Top 5 selected features: {selected_features}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15740\1545514717.py in ?()
#       3 x = df.drop('CLASS', axis = 1)
#       4 y = df['CLASS']
#       5
#       6 selector = SelectKBest(chi2, k=5)
# ----> 7 selector.fit(x,y)
#       8 x_selected = selector.transform(x)
#       9
#      10 selected_features = x.columns[selector.get_support()]
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py in ?(self, X, y)
#     463             Returns the instance itself.
#     464         """
#     465         self._validate_params()
#     466
# --> 467         X, y = self._validate_data(
#     468             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     469         )
#     470
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# 9 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       2 from sklearn.preprocessing import StandardScaler
#       4 scaler = StandardScaler()
# ----> 5 x_scaled = scaler.fit_transform(x_scaled)
#
# NameError: name 'x_scaled' is not defined

# %%
# 10 

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.2, stratify=y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       1 # 10
#       3 from sklearn.model_selection import train_test_split
# ----> 5 x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.2, stratify=y, random_state=42)
#
# NameError: name 'x_scaled' is not defined

# %%
#11
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import time

# %%
classifiers = { 'LR:' LogisticRegression(), 'DT:' DecisionTreeClassifier, 'RF:' RandomForestClassifier, 'SVC:' SVC(), 'NB:' GaussianNB()}

result = { 'classifier':[], 'Accuracy':[], 'Training Time(s)': []}

for name, clf in classifiers.items():
    start_time= time.time()
    clf.fit(x_train, y_train)
    training_time = time.time() -start_time
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    results['classifier'].append(name)
    results['accuracy'].append(accuracy)
    results['training time(s)'].append(training_time)
# Out:
#   Cell In[48], line 1
#     classifiers = { 'LR:' LogisticRegression(), 'DT:' DecisionTreeClassifier, 'RF:' RandomForestClassifier, 'SVC:' SVC(), 'NB:' GaussianNB()}
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#12

results_df = pd.DataFrame(reults)
print(results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 #12
# ----> 3 results_df = pd.DataFrame(reults)
#       4 print(results_df)
#
# NameError: name 'reults' is not defined
